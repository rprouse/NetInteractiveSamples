# %% [markdown]
# # Worldwide Covid Vaccinations

# %%
#r "nuget:System.Web.Http"
# Out:
# Installing package System.Web.Http.......

# %%
using System.Net.Http;
using System.Net.Http.Headers;
using System.Text.Json;

# %% [markdown]
# ## Create an HttpClient for the network calls

# %%
HttpClient client = new HttpClient();
client.DefaultRequestHeaders.Accept.Clear();
client.DefaultRequestHeaders.Accept.Add(new MediaTypeWithQualityHeaderValue("text/html"));
client.DefaultRequestHeaders.Accept.Add(new MediaTypeWithQualityHeaderValue("application/json"));
client.DefaultRequestHeaders.Add("User-Agent", "Notebooks (https://github.com/rprouse)");

# %% [markdown]
# ## Get the daily code from the HTML page

# %%
const string ROOT_URI = "https://static01.nyt.com/newsgraphics/2021/01/19/world-vaccinations-tracker/";

string html = await client.GetStringAsync("https://www.nytimes.com/interactive/2021/world/covid-vaccinations-tracker.html");
int start = html.IndexOf(ROOT_URI) + ROOT_URI.Length;
int end = html.IndexOf('/', start + 1);
string code = html.Substring(start, end - start);
display(code);
# Out:
# bb0d593d709fb0012ae5500c1a5ae70b7280c4fe

# %% [markdown]
# ## Get the JSON Vaccination Data

# %%
var json = await client.GetStringAsync($"{ROOT_URI}{code}/latest.json");
display(json);
# Out:
# [{"geoid":"EGY","location":"Egypt","last_updated":"2021-01-30","total_vaccinations":1315,"population":98423595},{"geoid":"MMR","location":"Myanmar","last_updated":"2021-02-05","total_vaccinations":380000,"people_vaccinated":380000,"population":53708395},{"geoid":"MUS","location":"Mauritius","last_updated":"2021-02-17","total_vaccinations":3843,"people_vaccinated":3843,"population":1265303},{"geoid":"DZA","location":"Algeria","last_updated":"2021-02-19","total_vaccinations":75000,"population":42228429},{"geoid":"TTO","location":"Trinidad and Tobago","last_updated":"2021-02-27","total_vaccinations":991,"people_vaccinated":991,"population":1389858},{"geoid":"GRL","location":"Greenland","last_updated":"2021-03-01","total_vaccinations":5130,"people_vaccinated":3927,"people_fully_vaccinated":1203,"population":56025},{"geoid":"MOZ","location":"Mozambique","last_updated":"2021-03-13","total_vaccinations":46439,"people_vaccinated":46439,"population":29495962},{"geoid":"AFG","location":"Afghanistan","last_updated":"2021-03-16","total_vaccinations":54000,"people_vaccinated":54000,"population":37172386},{"geoid":"MKD","location":"North Macedonia","last_updated":"2021-03-16","total_vaccinations":5300,"people_vaccinated":5300,"population":2082958},{"geoid":"BHS","location":"Bahamas","last_updated":"2021-03-17","total_vaccinations":110,"people_vaccinated":110,"population":385640},{"geoid":"LAO","location":"Laos","last_updated":"2021-03-17","total_vaccinations":40732,"people_vaccinated":40732,"population":7061507},{"geoid":"MSR","location":"Montserrat","last_updated":"2021-03-17","total_vaccinations":1306,"people_vaccinated":1112,"people_fully_vaccinated":194,"population":5900},{"geoid":"KAZ","location":"Kazakhstan","last_updated":"2021-03-18","total_vaccinations":109995,"people_vaccinated":90748,"people_fully_vaccinated":19247,"population":18276499},{"geoid":"AND","location":"Andorra","last_updated":"2021-03-19","total_vaccinations":9288,"population":77006},{"geoid":"AIA","location":"Anguilla","last_updated":"2021-03-19","total_vaccinations":5348,"people_vaccinated":5348,"population":14731},{"geoid":"IRN","location":"Iran","last_updated":"2021-03-19","total_vaccinations":124193,"population":81800269},{"geoid":"MCO","location":"Monaco","last_updated":"2021-03-19","total_vaccinations":18081,"people_vaccinated":9750,"people_fully_vaccinated":8331,"population":38682},{"geoid":"NPL","location":"Nepal","last_updated":"2021-03-19","total_vaccinations":1600000,"population":28087871},{"geoid":"CYP","location":"Cyprus","last_updated":"2021-03-20","total_vaccinations":129438,"people_vaccinated":93475,"people_fully_vaccinated":35963,"population":1189265},{"geoid":"HND","location":"Honduras","last_updated":"2021-03-21","total_vaccinations":43073,"people_vaccinated":43073,"population":9587522},{"geoid":"TCA","location":"Turks and Caicos Islands","last_updated":"2021-03-21","total_vaccinations":12935,"people_vaccinated":12935,"population":37665},{"geoid":"SVN","location":"Slovenia","last_updated":"2021-03-23","total_vaccinations":295780,"people_vaccinated":191217,"people_fully_vaccinated":104563,"population":2067372},{"geoid":"KHM","location":"Cambodia","last_updated":"2021-03-24","total_vaccinations":296149,"people_vaccinated":229079,"population":16249798},{"geoid":"CPV","location":"Cape Verde","last_updated":"2021-03-24","total_vaccinations":2184,"people_vaccinated":2184,"population":543767},{"geoid":"GHA","location":"Ghana","last_updated":"2021-03-24","total_vaccinations":500000,"people_vaccinated":500000,"population":29767108},{"geoid":"GRD","location":"Grenada","last_updated":"2021-03-24","total_vaccinations":9821,"people_vaccinated":9821,"population":111454},{"geoid":"PHL","location":"Philippines","last_updated":"2021-03-24","total_vaccinations":508332,"people_vaccinated":508332,"population":106651922},{"geoid":"TGO","location":"Togo","last_updated":"2021-03-24","total_vaccinations":42092,"people_vaccinated":42092,"population":7889094},{"geoid":"ATG" ...
